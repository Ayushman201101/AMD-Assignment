# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/home/ayush/Downloads/archive/covid_vaccine_statewise.csv')
df.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
df.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
df.shape
# Out:
# (7845, 24)

# %%
df['State'].unique()
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df.sort_values(['State'])
# Out:
#       Updated On                        State  Total Doses Administered  \
# 423   15/08/2021  Andaman and Nicobar Islands                       NaN
# 287   01/04/2021  Andaman and Nicobar Islands                   22608.0
# 286   31/03/2021  Andaman and Nicobar Islands                   21938.0
# 285   30/03/2021  Andaman and Nicobar Islands                   21840.0
# 284   29/03/2021  Andaman and Nicobar Islands                   21357.0
# ...          ...                          ...                       ...
# 7706  30/03/2021                  West Bengal                 5323718.0
# 7707  31/03/2021                  West Bengal                 5467439.0
# 7708  01/04/2021                  West Bengal                 5614451.0
# 7710  03/04/2021                  West Bengal                 5967900.0
# 7844  15/08/2021                  West Bengal                       NaN
#
#       Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
statewise_vaccination=df.groupby('State')['Total Individuals Vaccinated'].sum().to_frame('Total Individuals Vaccinated')
statewise_vaccination
# Out:
#                                           Total Individuals Vaccinated
# State
# Andaman and Nicobar Islands                               8.102125e+06
# Andhra Pradesh                                            5.645911e+08
# Arunachal Pradesh                                         2.108156e+07
# Assam                                                     2.397691e+08
# Bihar                                                     6.608479e+08
# Chandigarh                                                1.973150e+07
# Chhattisgarh                                              4.353092e+08
# Dadra and Nagar Haveli and Daman and Diu                  1.135860e+07
# Delhi                                                     3.057372e+08
# Goa                                                       3.211478e+07
# Gujarat                                                   1.078261e+09
# Haryana                                                   3.637547e+08
# ...

# %%
first_dose=df[['State','First Dose Administered']].groupby('State').sum()
first_dose
# Out:
#                                           First Dose Administered
# State
# Andaman and Nicobar Islands                          1.642585e+07
# Andhra Pradesh                                       1.232861e+09
# Arunachal Pradesh                                    4.900498e+07
# Assam                                                5.856002e+08
# Bihar                                                1.470503e+09
# Chandigarh                                           4.470310e+07
# Chhattisgarh                                         7.960029e+08
# Dadra and Nagar Haveli and Daman and Diu             3.359506e+07
# Delhi                                                6.243395e+08
# Goa                                                  7.599137e+07
# Gujarat                                              2.131646e+09
# Haryana                                              7.557984e+08
# Himachal Pradesh                                     3.162940e+08
# ...

# %%
second_dose=df[['State','Second Dose Administered']].groupby('State').sum()
second_dose
# Out:
#                                           Second Dose Administered
# State
# Andaman and Nicobar Islands                           4.118554e+06
# Andhra Pradesh                                        3.588176e+08
# Arunachal Pradesh                                     1.193232e+07
# Assam                                                 1.307888e+08
# Bihar                                                 2.707906e+08
# Chandigarh                                            1.159374e+07
# Chhattisgarh                                          1.721204e+08
# Dadra and Nagar Haveli and Daman and Diu              4.594416e+06
# Delhi                                                 1.882189e+08
# Goa                                                   1.619817e+07
# Gujarat                                               6.004184e+08
# Haryana                                               1.586561e+08
# Himachal Pradesh                                      7.383858e+07
# ...

# %%
statewise_vaccination=df[['State','Total Individuals Vaccinated']].groupby('State').sum()
statewise_vaccination
# Out:
#                                           Total Individuals Vaccinated
# State
# Andaman and Nicobar Islands                               8.102125e+06
# Andhra Pradesh                                            5.645911e+08
# Arunachal Pradesh                                         2.108156e+07
# Assam                                                     2.397691e+08
# Bihar                                                     6.608479e+08
# Chandigarh                                                1.973150e+07
# Chhattisgarh                                              4.353092e+08
# Dadra and Nagar Haveli and Daman and Diu                  1.135860e+07
# Delhi                                                     3.057372e+08
# Goa                                                       3.211478e+07
# Gujarat                                                   1.078261e+09
# Haryana                                                   3.637547e+08
# ...
